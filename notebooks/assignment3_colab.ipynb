# %% [markdown]
# # Assignment 3: Self Alignment with Instruction Backtranslation
#
# This notebook runs the full four-stage pipeline:
#
# 1. Train the backward model on Guanaco seed data.
# 2. Generate synthetic instructions from LIMA responses.
# 3. Curate synthetic data with few-shot quality scoring.
# 4. Train the final instruction-following model.

# %% [markdown]
# ## 1. Environment Setup

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !git clone <YOUR_REPO_URL>
# %cd /content/assignment3/assignment3
# !pip install -U pip
# !pip install -e .

# %% [markdown]
# ## 2. Hugging Face Login

# %%
from huggingface_hub import login
login()

# %% [markdown]
# ## 3. Train Backward Model

# %%
# !python scripts/train_backward.py --config configs/backward_train.json

# %% [markdown]
# Paste backward model Hugging Face URL here:
#
# - `TODO`

# %% [markdown]
# ## 4. Generate Synthetic Instructions

# %%
# !python scripts/generate_instructions.py --config configs/augmentation.json

# %% [markdown]
# Add 5 generated instruction examples here after the run.

# %% [markdown]
# ## 5. Curate The Dataset

# %%
# !python scripts/curate_dataset.py --config configs/curation.json

# %% [markdown]
# Add 5 high-quality and 5 low-quality examples here after the run.
#
# Paste curated dataset Hugging Face URL here:
#
# - `TODO`

# %% [markdown]
# ## 6. Train Final Instruction Model

# %%
# !python scripts/train_forward.py --config configs/forward_train.json

# %% [markdown]
# Add 5 final model response examples here after the run.
#
# Paste final model Hugging Face URL here:
#
# - `TODO`

# %% [markdown]
# ## 7. Submission Links
#
# - Backward model URL: `TODO`
# - Curated dataset URL: `TODO`
# - Final model URL: `TODO`
# - Colab notebook URL: `TODO`
